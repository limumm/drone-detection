# %%
import os
import json
import shutil
def process_images(source_folder, target_folder):
    image_count = 1
    label_folder = os.path.join(target_folder, "labels")
    image_folder_path = os.path.join(target_folder, "imgs")
    if not os.path.exists(label_folder):
        os.makedirs(label_folder)

    for folder_name in sorted(os.listdir(source_folder)):
        folder_path = os.path.join(source_folder, folder_name)

        if not os.path.isdir(folder_path):
            continue

        json_file_path = os.path.join(folder_path, "IR_label.json")
        

        with open(json_file_path, "r") as json_file:
            data = json.load(json_file)
            exist_list = data["exist"]
            gt_rect_list = data["gt_rect"]

            for i, (exist, gt_rect) in enumerate(zip(exist_list, gt_rect_list), 1):
                image_name = str(image_count).zfill(6) + ".jpg"
                txt_name = str(image_count).zfill(6) + ".txt"
                image_count += 1
                print('image_count' + str(image_count))
                image_path = os.path.join(folder_path, f"{i:06}.jpg")
                target_image_path = os.path.join(image_folder_path, image_name)

                shutil.copy(image_path, target_image_path)

                if exist == 1:
                    txt_file_path = os.path.join(label_folder, txt_name)
                    with open(txt_file_path, "w") as txt_file:
                        x_center = (gt_rect[0] + gt_rect[2] / 2) / 640
                        y_center = (gt_rect[1] + gt_rect[3] / 2) / 512
                        width = gt_rect[2] / 640
                        height = gt_rect[3] / 512
                        txt_file.write(f"0 {x_center:.6f} {y_center:.6f} {width:.6f} {height:.6f}\n")

# %%
if __name__ == "__main__":
    
    source_folder = './无人机检测与追踪/train/'
    train_path = './dataset/train/'

    if not os.path.exists(train_path):
        os.makedirs(train_path)

    process_images(source_folder, train_path)
# Out:
# image_count2
# image_count3
# image_count4
# image_count5
# image_count6
# image_count7
# image_count8
# image_count9
# image_count10
# image_count11
# image_count12
# image_count13
# image_count14
# image_count15
# image_count16
# image_count17
# image_count18
# image_count19
# image_count20
# image_count21
# image_count22
# image_count23
# image_count24
# image_count25
# image_count26
# image_count27
# image_count28
# image_count29
# image_count30
# image_count31
# image_count32
# image_count33
# image_count34
# image_count35
# image_count36
# image_count37
# image_count38
# image_count39
# image_count40
# image_count41
# image_count42
# image_count43
# image_count44
# image_count45
# image_count46
# image_count47
# image_count48
# image_count49
# image_count50
# image_count51
# image_count52
# image_count53
# image_count54
# image_count55
# image_count56
# image_count57
# image_count58
# image_count59
# image_count60
# image_count61
# image_count62
# image_count63
# image_count64
# image_count65
# image_count66
# image_count67
# image_count68
# image_count69
# image_count70
# image_count71
# image_count72
# image_count73
# image_count74
# image_count75
# image_count76
# image_count77
# image_count78
# image_count79
# image_count80
# image_count81
# image_count82
# image_count83
# image_count84
# image_count85
# image_count86
# image_count87
# image_count88
# image_count89
# image_count90
# image_count91
# image_count92
# image_count93
# image_count94
# image_count95
# image_count96
# image_count97
# image_count98
# image_count99
# image_count100
# image_count101
# image_count102
# image_count103
# image_count104
# image_count105
# image_count106
# image_count107
# image_count108
# image_count109
# image_count110
# image_count111
# image_count112
# image_count113
# image_count114
# image_count115
# image_count116
# image_count117
# image_count118
# image_count119
# image_count120
# image_count121
# image_count122
# image_count123
# image_count124
# image_count125
# image_count126
# image_count127
# image_count128
# image_count129
# image_count130
# image_count131
# image_count132
# image_count133
# image_count134
# image_count135
# image_count136
# image_count137
# image_count138
# image_count139
# image_count140
# image_count141
# image_count142
# image_count143
# image_count144
# image_count145
# image_count146
# image_count147
# image_count148
# image_count149
# image_count150
# image_count151
# image_count152
# image_count153
# image_count154
# image_count155
# image_count156
# image_count157
# image_count158
# image_count159
# image_count160
# image_count161
# image_count162
# image_count163
# image_count164
# image_count165
# image_count166
# image_count167
# image_count168
# image_count169
# image_count170
# image_count171
# image_count172
# image_count173
# image_count174
# image_count175
# image_count176
# image_count177
# image_count178
# image_count179
# image_count180
# image_count181
# image_count182
# image_count183
# image_count184
# image_count185
# image_count186
# image_count187
# image_count188
# image_count189
# image_count190
# image_count191
# image_count192
# image_count193
# image_count194
# image_count195
# image_count196
# image_count197
# image_count198
# image_count199
# image_count200
# image_count201
# image_count202
# image_count203
# image_count204
# image_count205
# image_count206
# image_count207
# image_count208
# image_count209
# image_count210
# image_count211
# image_count212
# image_count213
# image_count214
# image_count215
# image_count216
# image_count217
# image_count218
# image_count219
# image_count220
# image_count221
# image_count222
# image_count223
# image_count224
# image_count225
# image_count226
# image_count227
# image_count228
# image_count229
# image_count230
# image_count231
# image_count232
# image_count233
# image_count234
# image_count235
# image_count236
# image_count237
# image_count238
# image_count239
# image_count240
# image_count241
# image_count242
# image_count243
# image_count244
# image_count245
# image_count246
# image_count247
# image_count248
# image_count249
# image_count250
# image_count251
# image_count252
# image_count253
# image_count254
# image_count255
# image_count256
# image_count257
# image_count258
# image_count259
# image_count260
# image_count261
# image_count262
# image_count263
# image_count264
# image_count265
# image_count266
# image_count267
# image_count268
# image_count269
# image_count270
# image_count271
# image_count272
# image_count273
# image_count274
# image_count275
# image_count276
# image_count277
# image_count278
# image_count279
# image_count280
# image_count281
# image_count282
# image_count283
# image_count284
# image_count285
# image_count286
# image_count287
# image_count288
# image_count289
# image_count290
# image_count291
# image_count292
# image_count293
# image_count294
# image_count295
# image_count296
# image_count297
# image_count298
# image_count299
# image_count300
# image_count301
# image_count302
# image_count303
# image_count304
# image_count305
# image_count306
# image_count307
# image_count308
# image_count309
# image_count310
# image_count311
# image_count312
# image_count313
# image_count314
# image_count315
# image_count316
# image_count317
# image_count318
# image_count319
# image_count320
# image_count321
# image_count322
# image_count323
# image_count324
# image_count325
# image_count326
# image_count327
# image_count328
# image_count329
# image_count330
# image_count331
# image_count332
# image_count333
# image_count334
# image_count335
# image_count336
# image_count337
# image_count338
# image_count339
# image_count340
# image_count341
# image_count342
# image_count343
# image_count344
# image_count345
# image_count346
# image_count347
# image_count348
# image_count349
# image_count350
# image_count351
# image_count352
# image_count353
# image_count354
# image_count355
# image_count356
# image_count357
# image_count358
# image_count359
# image_count360
# image_count361
# image_count362
# image_count363
# image_count364
# image_count365
# image_count366
# image_count367
# image_count368
# image_count369
# image_count370
# image_count371
# image_count372
# image_count373
# image_count374
# image_count375
# image_count376
# image_count377
# image_count378
# image_count379
# image_count380
# image_count381
# image_count382
# image_count383
# image_count384
# image_count385
# image_count386
# image_count387
# image_count388
# image_count389
# image_count390
# image_count391
# image_count392
# image_count393
# image_count394
# image_count395
# image_count396
# image_count397
# image_count398
# image_count399
# image_count400
# image_count401
# image_count402
# image_count403
# image_count404
# image_count405
# image_count406
# image_count407
# image_count408
# image_count409
# image_count410
# image_count411
# image_count412
# image_count413
# image_count414
# image_count415
# image_count416
# image_count417
# image_count418
# image_count419
# image_count420
# image_count421
# image_count422
# image_count423
# image_count424
# image_count425
# image_count426
# image_count427
# image_count428
# image_count429
# image_count430
# image_count431
# image_count432
# image_count433
# image_count434
# image_count435
# image_count436
# image_count437
# image_count438
# image_count439
# image_count440
# image_count441
# image_count442
# image_count443
# image_count444
# image_count445
# image_count446
# image_count447
# image_count448
# image_count449
# image_count450
# image_count451
# image_count452
# image_count453
# image_count454
# image_count455
# image_count456
# image_count457
# image_count458
# image_count459
# image_count460
# image_count461
# image_count462
# image_count463
# image_count464
# image_count465
# image_count466
# image_count467
# image_count468
# image_count469
# image_count470
# image_count471
# image_count472
# image_count473
# image_count474
# image_count475
# image_count476
# image_count477
# image_count478
# image_count479
# image_count480
# image_count481
# image_count482
# image_count483
# image_count484
# image_count485
# image_count486
# image_count487
# image_count488
# image_count489
# image_count490
# image_count491
# image_count492
# image_count493
# image_count494
# image_count495
# image_count496
# image_count497
# image_count498
# image_count499
# image_count500
# image_count501
# image_count502
# image_count503
# image_count504
# image_count505
# image_count506
# image_count507
# image_count508
# image_count509
# image_count510
# image_count511
# image_count512
# image_count513
# image_count514
# image_count515
# image_count516
# image_count517
# image_count518
# image_count519
# image_count520
# image_count521
# image_count522
# image_count523
# image_count524
# image_count525
# image_count526
# image_count527
# image_count528
# image_count529
# image_count530
# image_count531
# image_count532
# image_count533
# image_count534
# image_count535
# image_count536
# image_count537
# image_count538
# image_count539
# image_count540
# image_count541
# image_count542
# image_count543
# image_count544
# image_count545
# image_count546
# image_count547
# image_count548
# image_count549
# image_count550
# image_count551
# image_count552
# image_count553
# image_count554
# image_count555
# image_count556
# image_count557
# image_count558
# image_count559
# image_count560
# image_count561
# image_count562
# image_count563
# image_count564
# image_count565
# image_count566
# image_count567
# image_count568
# image_count569
# image_count570
# image_count571
# image_count572
# image_count573
# image_count574
# image_count575
# image_count576
# image_count577
# image_count578
# image_count579
# image_count580
# image_count581
# image_count582
# image_count583
# image_count584
# image_count585
# image_count586
# image_count587
# image_count588
# image_count589
# image_count590
# image_count591
# image_count592
# image_count593
# image_count594
# image_count595
# image_count596
# image_count597
# image_count598
# image_count599
# image_count600
# image_count601
# image_count602
# image_count603
# image_count604
# image_count605
# image_count606
# image_count607
# image_count608
# image_count609
# image_count610
# image_count611
# image_count612
# image_count613
# image_count614
# image_count615
# image_count616
# image_count617
# image_count618
# image_count619
# image_count620
# image_count621
# image_count622
# image_count623
# image_count624
# image_count625
# image_count626
# image_count627
# image_count628
# image_count629
# image_count630
# image_count631
# image_count632
# image_count633
# image_count634
# image_count635
# image_count636
# image_count637
# image_count638
# image_count639
# image_count640
# image_count641
# image_count642
# image_count643
# image_count644
# image_count645
# image_count646
# image_count647
# image_count648
# image_count649
# image_count650
# image_count651
# image_count652
# image_count653
# image_count654
# image_count655
# image_count656
# image_count657
# image_count658
# image_count659
# image_count660
# image_count661
# image_count662
# image_count663
# image_count664
# image_count665
# image_count666
# image_count667
# image_count668
# image_count669
# image_count670
# image_count671
# image_count672
# image_count673
# image_count674
# image_count675
# image_count676
# image_count677
# image_count678
# image_count679
# image_count680
# image_count681
# image_count682
# image_count683
# image_count684
# image_count685
# image_count686
# image_count687
# image_count688
# image_count689
# image_count690
# image_count691
# image_count692
# image_count693
# image_count694
# image_count695
# image_count696
# image_count697
# image_count698
# image_count699
# image_count700
# image_count701
# image_count702
# image_count703
# image_count704
# image_count705
# image_count706
# image_count707
# image_count708
# image_count709
# image_count710
# image_count711
# image_count712
# image_count713
# image_count714
# image_count715
# image_count716
# image_count717
# image_count718
# image_count719
# image_count720
# image_count721
# image_count722
# image_count723
# image_count724
# image_count725
# image_count726
# image_count727
# image_count728
# image_count729
# image_count730
# image_count731
# image_count732
# image_count733
# image_count734
# image_count735
# image_count736
# image_count737
# image_count738
# image_count739
# image_count740
# image_count741
# image_count742
# image_count743
# image_count744
# image_count745
# image_count746
# image_count747
# image_count748
# image_count749
# image_count750
# image_count751
# image_count752
# image_count753
# image_count754
# image_count755
# image_count756
# image_count757
# image_count758
# image_count759
# image_count760
# image_count761
# image_count762
# image_count763
# image_count764
# image_count765
# image_count766
# image_count767
# image_count768
# image_count769
# image_count770
# image_count771
# image_count772
# image_count773
# image_count774
# image_count775
# image_count776
# image_count777
# image_count778
# image_count779
# image_count780
# image_count781
# image_count782
# image_count783
# image_count784
# image_count785
# image_count786
# image_count787
# image_count788
# image_count789
# image_count790
# image_count791
# image_count792
# image_count793
# image_count794
# image_count795
# image_count796
# image_count797
# image_count798
# image_count799
# image_count800
# image_count801
# image_count802
# image_count803
# image_count804
# image_count805
# image_count806
# image_count807
# image_count808
# image_count809
# image_count810
# image_count811
# image_count812
# image_count813
# image_count814
# image_count815
# image_count816
# image_count817
# image_count818
# image_count819
# image_count820
# image_count821
# image_count822
# image_count823
# image_count824
# image_count825
# image_count826
# image_count827
# image_count828
# image_count829
# image_count830
# image_count831
# image_count832
# image_count833
# image_count834
# image_count835
# image_count836
# image_count837
# image_count838
# image_count839
# image_count840
# image_count841
# image_count842
# image_count843
# image_count844
# image_count845
# image_count846
# image_count847
# image_count848
# image_count849
# image_count850
# image_count851
# image_count852
# image_count853
# image_count854
# image_count855
# image_count856
# image_count857
# image_count858
# image_count859
# image_count860
# image_count861
# image_count862
# image_count863
# image_count864
# image_count865
# image_count866
# image_count867
# image_count868
# image_count869
# image_count870
# image_count871
# image_count872
# image_count873
# image_count874
# image_count875
# image_count876
# image_count877
# image_count878
# image_count879
# image_count880
# image_count881
# image_count882
# image_count883
# image_count884
# image_count885
# image_count886
# image_count887
# image_count888
# image_count889
# image_count890
# image_count891
# image_count892
# image_count893
# image_count894
# image_count895
# image_count896
# image_count897
# image_count898
# image_count899
# image_count900
# image_count901
# image_count902
# image_count903
# image_count904
# image_count905
# image_count906
# image_count907
# image_count908
# image_count909
# image_count910
# image_count911
# image_count912
# image_count913
# image_count914
# image_count915
# image_count916
# image_count917
# image_count918
# image_count919
# image_count920
# image_count921
# image_count922
# image_count923
# image_count924
# image_count925
# image_count926
# image_count927
# image_count928
# image_count929
# image_count930
# image_count931
# image_count932
# image_count933
# image_count934
# image_count935
# image_count936
# image_count937
# image_count938
# image_count939
# image_count940
# image_count941
# image_count942
# image_count943
# image_count944
# image_count945
# image_count946
# image_count947
# image_count948
# image_count949
# image_count950
# image_count951
# image_count952
# image_count953
# image_count954
# image_count955
# image_count956
# image_count957
# image_count958
# image_count959
# image_count960
# image_count961
# image_count962
# image_count963
# image_count964
# image_count965
# image_count966
# image_count967
# image_count968
# image_count969
# image_count970
# image_count971
# image_count972
# image_count973
# image_count974
# image_count975
# image_count976
# image_count977
# image_count978
# image_count979
# image_count980
# image_count981
# image_count982
# image_count983
# image_count984
# image_count985
# image_count986
# image_count987
# image_count988
# image_count989
# image_count990
# image_count991
# image_count992
# image_count993
# image_count994
# image_count995
# image_count996
# image_count997
# image_count998
# image_count999
# image_count1000
# image_count1001
# image_count1002
# image_count1003
# image_count1004
# image_count1005
# image_count1006
# image_count1007
# image_count1008
# image_count1009
# image_count1010
# image_count1011
# image_count1012
# image_count1013
# image_count1014
# image_count1015
# image_count1016
# image_count1017
# image_count1018
# image_count1019
# image_count1020
# image_count1021
# image_count1022
# image_count1023
# image_count1024
# image_count1025
# image_count1026
# image_count1027
# image_count1028
# image_count1029
# image_count1030
# image_count1031
# image_count1032
# image_count1033
# image_count1034
# image_count1035
# image_count1036
# image_count1037
# image_count1038
# image_count1039
# image_count1040
# image_count1041
# image_count1042
# image_count1043
# image_count1044
# image_count1045
# image_count1046
# image_count1047
# image_count1048
# image_count1049
# image_count1050
# image_count1051
# image_count1052
# image_count1053
# image_count1054
# image_count1055
# image_count1056
# image_count1057
# image_count1058
# image_count1059
# image_count1060
# image_count1061
# image_count1062
# image_count1063
# image_count1064
# image_count1065
# image_count1066
# image_count1067
# image_count1068
# image_count1069
# image_count1070
# image_count1071
# image_count1072
# image_count1073
# image_count1074
# image_count1075
# image_count1076
# image_count1077
# image_count1078
# image_count1079
# image_count1080
# image_count1081
# image_count1082
# image_count1083
# image_count1084
# image_count1085
# image_count1086
# image_count1087
# image_count1088
# image_count1089
# image_count1090
# image_count1091
# image_count1092
# image_count1093
# image_count1094
# image_count1095
# image_count1096
# image_count1097
# image_count1098
# image_count1099
# image_count1100
# image_count1101
# image_count1102
# image_count1103
# image_count1104
# image_count1105
# image_count1106
# image_count1107
# image_count1108
# image_count1109
# image_count1110
# image_count1111
# image_count1112
# image_count1113
# image_count1114
# image_count1115
# image_count1116
# image_count1117
# image_count1118
# image_count1119
# image_count1120
# image_count1121
# image_count1122
# image_count1123
# image_count1124
# image_count1125
# image_count1126
# image_count1127
# image_count1128
# image_count1129
# image_count1130
# image_count1131
# image_count1132
# image_count1133
# image_count1134
# image_count1135
# image_count1136
# image_count1137
# image_count1138
# image_count1139
# image_count1140
# image_count1141
# image_count1142
# image_count1143
# image_count1144
# image_count1145
# image_count1146
# image_count1147
# image_count1148
# image_count1149
# image_count1150
# image_count1151
# image_count1152
# image_count1153
# image_count1154
# image_count1155
# image_count1156
# image_count1157
# image_count1158
# image_count1159
# image_count1160
# image_count1161
# image_count1162
# image_count1163
# image_count1164
# image_count1165
# image_count1166
# image_count1167
# image_count1168
# image_count1169
# image_count1170
# image_count1171
# image_count1172
# image_count1173
# image_count1174
# image_count1175
# image_count1176
# image_count1177
# image_count1178
# image_count1179
# image_count1180
# image_count1181
# image_count1182
# image_count1183
# image_count1184
# image_count1185
# image_count1186
# image_count1187
# image_count1188
# image_count1189
# image_count1190
# image_count1191
# image_count1192
# image_count1193
# image_count1194
# image_count1195
# image_count1196
# image_count1197
# image_count1198
# image_count1199
# image_count1200
# image_count1201
# image_count1202
# image_count1203
# image_count1204
# image_count1205
# image_count1206
# image_count1207
# image_count1208
# image_count1209
# image_count1210
# image_count1211
# image_count1212
# image_count1213
# image_count1214
# image_count1215
# image_count1216
# image_count1217
# image_count1218
# image_count1219
# image_count1220
# image_count1221
# image_count1222
# image_count1223
# image_count1224
# image_count1225
# image_count1226
# image_count1227
# image_count1228
# image_count1229
# image_count1230
# image_count1231
# image_count1232
# image_count1233
# image_count1234
# image_count1235
# image_count1236
# image_count1237
# image_count1238
# image_count1239
# image_count1240
# image_count1241
# image_count1242
# image_count1243
# image_count1244
# image_count1245
# image_count1246
# image_count1247
# image_count1248
# image_count1249
# image_count1250
# image_count1251
# image_count1252
# image_count1253
# image_count1254
# image_count1255
# image_count1256
# image_count1257
# image_count1258
# image_count1259
# image_count1260
# image_count1261
# image_count1262
# image_count1263
# image_count1264
# image_count1265
# image_count1266
# image_count1267
# image_count1268
# image_count1269
# image_count1270
# image_count1271
# image_count1272
# image_count1273
# image_count1274
# image_count1275
# image_count1276
# image_count1277
# image_count1278
# image_count1279
# image_count1280
# image_count1281
# image_count1282
# image_count1283
# image_count1284
# image_count1285
# image_count1286
# image_count1287
# image_count1288
# image_count1289
# image_count1290
# image_count1291
# image_count1292
# image_count1293
# image_count1294
# image_count1295
# image_count1296
# image_count1297
# image_count1298
# image_count1299
# image_count1300
# image_count1301
# image_count1302
# image_count1303
# image_count1304
# image_count1305
# image_count1306
# image_count1307
# image_count1308
# image_count1309
# image_count1310
# image_count1311
# image_count1312
# image_count1313
# image_count1314
# image_count1315
# image_count1316
# image_count1317
# image_count1318
# image_count1319
# image_count1320
# image_count1321
# image_count1322
# image_count1323
# image_count1324
# image_count1325
# image_count1326
# image_count1327
# image_count1328
# image_count1329
# image_count1330
# image_count1331
# image_count1332
# image_count1333
# image_count1334
# image_count1335
# image_count1336
# image_count1337
# image_count1338
# image_count1339
# image_count1340
# image_count1341
# image_count1342
# image_count1343
# image_count1344
# image_count1345
# image_count1346
# image_count1347
# image_count1348
# image_count1349
# image_count1350
# image_count1351
# image_count1352
# image_count1353
# image_count1354
# image_count1355
# image_count1356
# image_count1357
# image_count1358
# image_count1359
# image_count1360
# image_count1361
# image_count1362
# image_count1363
# image_count1364
# image_count1365
# image_count1366
# image_count1367
# image_count1368
# image_count1369
# image_count1370
# image_count1371
# image_count1372
# image_count1373
# image_count1374
# image_count1375
# image_count1376
# image_count1377
# image_count1378
# image_count1379
# image_count1380
# image_count1381
# image_count1382
# image_count1383
# image_count1384
# image_count1385
# image_count1386
# image_count1387
# image_count1388
# image_count1389
# image_count1390
# image_count1391
# image_count1392
# image_count1393
# image_count1394
# image_count1395
# image_count1396
# image_count1397
# image_count1398
# image_count1399
# image_count1400
# image_count1401
# image_count1402
# image_count1403
# image_count1404
# image_count1405
# image_count1406
# image_count1407
# image_count1408
# image_count1409
# image_count1410
# image_count1411
# image_count1412
# image_count1413
# image_count1414
# image_count1415
# image_count1416
# image_count1417
# image_count1418
# image_count1419
# image_count1420
# image_count1421
# image_count1422
# image_count1423
# image_count1424
# image_count1425
# image_count1426
# image_count1427
# image_count1428
# image_count1429
# image_count1430
# image_count1431
# image_count1432
# image_count1433
# image_count1434
# image_count1435
# image_count1436
# image_count1437
# image_count1438
# image_count1439
# image_count1440
# image_count1441
# image_count1442
# image_count1443
# image_count1444
# image_count1445
# image_count1446
# image_count1447
# image_count1448
# image_count1449
# image_count1450
# image_count1451
# image_count1452
# image_count1453
# image_count1454
# image_count1455
# image_count1456
# image_count1457
# image_count1458
# image_count1459
# image_count1460
# image_count1461
# image_count1462
# image_count1463
# image_count1464
# image_count1465
# image_count1466
# image_count1467
# image_count1468
# image_count1469
# image_count1470
# image_count1471
# image_count1472
# image_count1473
# image_count1474
# image_count1475
# image_count1476
# image_count1477
# image_count1478
# image_count1479
# image_count1480
# image_count1481
# image_count1482
# image_count1483
# image_count1484
# image_count1485
# image_count1486
# image_count1487
# image_count1488
# image_count1489
# image_count1490
# image_count1491
# image_count1492
# image_count1493
# image_count1494
# image_count1495
# image_count1496
# image_count1497
# image_count1498
# image_count1499
# image_count1500
# image_count1501
# image_count1502
# image_count1503
# image_count1504
# image_count1505
# image_count1506
# image_count1507
# image_count1508
# image_count1509
# image_count1510
# image_count1511
# image_count1512
# image_count1513
# image_count1514
# image_count1515
# image_count1516
# image_count1517
# image_count1518
# image_count1519
# image_count1520
# image_count1521
# image_count1522
# image_count1523
# image_count1524
# image_count1525
# image_count1526
# image_count1527
# image_count1528
# image_count1529
# image_count1530
# image_count1531
# image_count1532
# image_count1533
# image_count1534
# image_count1535
# image_count1536
# image_count1537
# image_count1538
# image_count1539
# image_count1540
# image_count1541
# image_count1542
# image_count1543
# image_count1544
# image_count1545
# image_count1546
# image_count1547
# image_count1548
# image_count1549
# image_count1550
# image_count1551
# image_count1552
# image_count1553
# image_count1554
# image_count1555
# image_count1556
# image_count1557
# image_count1558
# image_count1559
# image_count1560
# image_count1561
# image_count1562
# image_count1563
# image_count1564
# image_count1565
# image_count1566
# image_count1567
# image_count1568
# image_count1569
# image_count1570
# image_count1571
# image_count1572
# image_count1573
# image_count1574
# image_count1575
# image_count1576
# image_count1577
# image_count1578
# image_count1579
# image_count1580
# image_count1581
# image_count1582
# image_count1583
# image_count1584
# image_count1585
# image_count1586
# image_count1587
# image_count1588
# image_count1589
# image_count1590
# image_count1591
# image_count1592
# image_count1593
# image_count1594
# image_count1595
# image_count1596
# image_count1597
# image_count1598
# image_count1599
# image_count1600
# image_count1601
# image_count1602
# image_count1603
# image_count1604
# image_count1605
# image_count1606
# image_count1607
# image_count1608
# image_count1609
# image_count1610
# image_count1611
# image_count1612
# image_count1613
# image_count1614
# image_count1615
# image_count1616
# image_count1617
# image_count1618
# image_count1619
# image_count1620
# image_count1621
# image_count1622
# image_count1623
# image_count1624
# image_count1625
# image_count1626
# image_count1627
# image_count1628
# image_count1629
# image_count1630
# image_count1631
# image_count1632
# image_count1633
# image_count1634
# image_count1635
# image_count1636
# image_count1637
# image_count1638
# image_count1639
# image_count1640
# image_count1641
# image_count1642
# image_count1643
# image_count1644
# image_count1645
# image_count1646
# image_count1647
# image_count1648
# image_count1649
# image_count1650
# image_count1651
# image_count1652
# image_count1653
# image_count1654
# image_count1655
# image_count1656
# image_count1657
# image_count1658
# image_count1659
# image_count1660
# image_count1661
# image_count1662
# image_count1663
# image_count1664
# image_count1665
# image_count1666
# image_count1667
# image_count1668
# image_count1669
# image_count1670
# image_count1671
# image_count1672
# image_count1673
# image_count1674
# image_count1675
# image_count1676
# image_count1677
# image_count1678
# image_count1679
# image_count1680
# image_count1681
# image_count1682
# image_count1683
# image_count1684
# image_count1685
# image_count1686
# image_count1687
# image_count1688
# image_count1689
# image_count1690
# image_count1691
# image_count1692
# image_count1693
# image_count1694
# image_count1695
# image_count1696
# image_count1697
# image_count1698
# image_count1699
# image_count1700
# image_count1701
# image_count1702
# image_count1703
# image_count1704
# image_count1705
# image_count1706
# image_count1707
# image_count1708
# image_count1709
# image_count1710
# image_count1711
# image_count1712
# image_count1713
# image_count1714
# image_count1715
# image_count1716
# image_count1717
# image_count1718
# image_count1719
# image_count1720
# image_count1721
# image_count1722
# image_count1723
# image_count1724
# image_count1725
# image_count1726
# image_count1727
# image_count1728
# image_count1729
# image_count1730
# image_count1731
# image_count1732
# image_count1733
# image_count1734
# image_count1735
# image_count1736
# image_count1737
# image_count1738
# image_count1739
# image_count1740
# image_count1741
# image_count1742
# image_count1743
# image_count1744
# image_count1745
# image_count1746
# image_count1747
# image_count1748
# image_count1749
# image_count1750
# image_count1751
# image_count1752
# image_count1753
# image_count1754
# image_count1755
# image_count1756
# image_count1757
# image_count1758
# image_count1759
# image_count1760
# image_count1761
# image_count1762
# image_count1763
# image_count1764
# image_count1765
# image_count1766
# image_count1767
# image_count1768
# image_count1769
# image_count1770
# image_count1771
# image_count1772
# image_count1773
# image_count1774
# image_count1775
# image_count1776
# image_count1777
# image_count1778
# image_count1779
# image_count1780
# image_count1781
# image_count1782
# image_count1783
# image_count1784
# image_count1785
# image_count1786
# image_count1787
# image_count1788
# image_count1789
# image_count1790
# image_count1791
# image_count1792
# image_count1793
# image_count1794
# image_count1795
# image_count1796
# image_count1797
# image_count1798
# image_count1799
# image_count1800
# image_count1801
# image_count1802
# image_count1803
# image_count1804
# image_count1805
# image_count1806
# image_count1807
# image_count1808
# image_count1809
# image_count1810
# image_count1811
# image_count1812
# image_count1813
# image_count1814
# image_count1815
# image_count1816
# image_count1817
# image_count1818
# image_count1819
# image_count1820
# image_count1821
# image_count1822
# image_count1823
# image_count1824
# image_count1825
# image_count1826
# image_count1827
# image_count1828
# image_count1829
# image_count1830
# image_count1831
# image_count1832
# image_count1833
# image_count1834
# image_count1835
# image_count1836
# image_count1837
# image_count1838
# image_count1839
# image_count1840
# image_count1841
# image_count1842
# image_count1843
# image_count1844
# image_count1845
# image_count1846
# image_count1847
# image_count1848
# image_count1849
# image_count1850
# image_count1851
# image_count1852
# image_count1853
# image_count1854
# image_count1855
# image_count1856
# image_count1857
# image_count1858
# image_count1859
# image_count1860
# image_count1861
# image_count1862
# image_count1863
# image_count1864
# image_count1865
# image_count1866
# image_count1867
# image_count1868
# image_count1869
# image_count1870
# image_count1871
# image_count1872
# image_count1873
# image_count1874
# image_count1875
# image_count1876
# image_count1877
# image_count1878
# image_count1879
# image_count1880
# image_count1881
# image_count1882
# image_count1883
# image_count1884
# image_count1885
# image_count1886
# image_count1887
# image_count1888
# image_count1889
# image_count1890
# image_count1891
# image_count1892
# image_count1893
# image_count1894
# image_count1895
# image_count1896
# image_count1897
# image_count1898
# image_count1899
# image_count1900
# image_count1901
# image_count1902
# image_count1903
# image_count1904
# image_count1905
# image_count1906
# image_count1907
# image_count1908
# image_count1909
# image_count1910
# image_count1911
# image_count1912
# image_count1913
# image_count1914
# image_count1915
# image_count1916
# image_count1917
# image_count1918
# image_count1919
# image_count1920
# image_count1921
# image_count1922
# image_count1923
# image_count1924
# image_count1925
# image_count1926
# image_count1927
# image_count1928
# image_count1929
# image_count1930
# image_count1931
# image_count1932
# image_count1933
# image_count1934
# image_count1935
# image_count1936
# image_count1937
# image_count1938
# image_count1939
# image_count1940
# image_count1941
# image_count1942
# image_count1943
# image_count1944
# image_count1945
# image_count1946
# image_count1947
# image_count1948
# image_count1949
# image_count1950
# image_count1951
# image_count1952
# image_count1953
# image_count1954
# image_count1955
# image_count1956
# image_count1957
# image_count1958
# image_count1959
# image_count1960
# image_count1961
# image_count1962
# image_count1963
# image_count1964
# image_count1965
# image_count1966
# image_count1967
# image_count1968
# image_count1969
# image_count1970
# image_count1971
# image_count1972
# image_count1973
# image_count1974
# image_count1975
# image_count1976
# image_count1977
# image_count1978
# image_count1979
# image_count1980
# image_count1981
# image_count1982
# image_count1983
# image_count1984
# image_count1985
# image_count1986
# image_count1987
# image_count1988
# image_count1989
# image_count1990
# image_count1991
# image_count1992
# image_count1993
# image_count1994
# image_count1995
# image_count1996
# image_count1997
# image_count1998
# image_count1999
# image_count2000
# image_count2001
# image_count2002
# image_count2003
# image_count2004
# image_count2005
# image_count2006
# image_count2007
# image_count2008
# image_count2009
# image_count2010
# image_count2011
# image_count2012
# image_count2013
# image_count2014
# image_count2015
# image_count2016
# image_count2017
# image_count2018
# image_count2019
# image_count2020
# image_count2021
# image_count2022
# image_count2023
# image_count2024
# image_count2025
# image_count2026
# image_count2027
# image_count2028
# image_count2029
# image_count2030
# image_count2031
# image_count2032
# image_count2033
# image_count2034
# image_count2035
# image_count2036
# image_count2037
# image_count2038
# image_count2039
# image_count2040
# image_count2041
# image_count2042
# image_count2043
# image_count2044
# image_count2045
# image_count2046
# image_count2047
# image_count2048
# image_count2049
# image_count2050
# image_count2051
# image_count2052
# image_count2053
# image_count2054
# image_count2055
# image_count2056
# image_count2057
# image_count2058
# image_count2059
# image_count2060
# image_count2061
# image_count2062
# image_count2063
# image_count2064
# image_count2065
# image_count2066
# image_count2067
# image_count2068
# image_count2069
# image_count2070
# image_count2071
# image_count2072
# image_count2073
# image_count2074
# image_count2075
# image_count2076
# image_count2077
# image_count2078
# image_count2079
# image_count2080
# image_count2081
# image_count2082
# image_count2083
# image_count2084
# image_count2085
# image_count2086
# image_count2087
# image_count2088
# image_count2089
# image_count2090
# image_count2091
# image_count2092
# image_count2093
# image_count2094
# image_count2095
# image_count2096
# image_count2097
# image_count2098
# image_count2099
# image_count2100
# image_count2101
# image_count2102
# image_count2103
# image_count2104
# image_count2105
# image_count2106
# image_count2107
# image_count2108
# image_count2109
# image_count2110
# image_count2111
# image_count2112
# image_count2113
# image_count2114
# image_count2115
# image_count2116
# image_count2117
# image_count2118
# image_count2119
# image_count2120
# image_count2121
# image_count2122
# image_count2123
# image_count2124
# image_count2125
# image_count2126
# image_count2127
# image_count2128
# image_count2129
# image_count2130
# image_count2131
# image_count2132
# image_count2133
# image_count2134
# image_count2135
# image_count2136
# image_count2137
# image_count2138
# image_count2139
# image_count2140
# image_count2141
# image_count2142
# image_count2143
# image_count2144
# image_count2145
# image_count2146
# image_count2147
# image_count2148
# image_count2149
# image_count2150
# image_count2151
# image_count2152
# image_count2153
# image_count2154
# image_count2155
# image_count2156
# image_count2157
# image_count2158
# image_count2159
# image_count2160
# image_count2161
# image_count2162
# image_count2163
# image_count2164
# image_count2165
# image_count2166
# image_count2167
# image_count2168
# image_count2169
# image_count2170
# image_count2171
# image_count2172
# image_count2173
# image_count2174
# image_count2175
# image_count2176
# image_count2177
# image_count2178
# image_count2179
# image_count2180
# image_count2181
# image_count2182
# image_count2183
# image_count2184
# image_count2185
# image_count2186
# image_count2187
# image_count2188
# image_count2189
# image_count2190
# image_count2191
# image_count2192
# image_count2193
# image_count2194
# image_count2195
# image_count2196
# image_count2197
# image_count2198
# image_count2199
# image_count2200
# image_count2201
# image_count2202
# image_count2203
# image_count2204
# image_count2205
# image_count2206
# image_count2207
# image_count2208
# image_count2209
# image_count2210
# image_count2211
# image_count2212
# image_count2213
# image_count2214
# image_count2215
# image_count2216
# image_count2217
# image_count2218
# image_count2219
# image_count2220
# image_count2221
# image_count2222
# image_count2223
# image_count2224
# image_count2225
# image_count2226
# image_count2227
# image_count2228
# image_count2229
# image_count2230
# image_count2231
# image_count2232
# image_count2233
# image_count2234
# image_count2235
# image_count2236
# image_count2237
# image_count2238
# image_count2239
# image_count2240
# image_count2241
# image_count2242
# image_count2243
# image_count2244
# image_count2245
# image_count2246
# image_count2247
# image_count2248
# image_count2249
# image_count2250
# image_count2251
# image_count2252
# image_count2253
# image_count2254
# image_count2255
# image_count2256
# image_count2257
# image_count2258
# image_count2259
# image_count2260
# image_count2261
# image_count2262
# image_count2263
# image_count2264
# image_count2265
# image_count2266
# image_count2267
# image_count2268
# image_count2269
# image_count2270
# image_count2271
# image_count2272
# image_count2273
# image_count2274
# image_count2275
# image_count2276
# image_count2277
# image_count2278
# image_count2279
# image_count2280
# image_count2281
# image_count2282
# image_count2283
# image_count2284
# image_count2285
# image_count2286
# image_count2287
# image_count2288
# image_count2289
# image_count2290
# image_count2291
# image_count2292
# image_count2293
# image_count2294
# image_count2295
# image_count2296
# image_count2297
# image_count2298
# image_count2299
# image_count2300
# image_count2301
# image_count2302
# image_count2303
# image_count2304
# image_count2305
# image_count2306
# image_count2307
# image_count2308
# image_count2309
# image_count2310
# image_count2311
# image_count2312
# image_count2313
# image_count2314
# image_count2315
# image_count2316
# image_count2317
# image_count2318
# image_count2319
# image_count2320
# image_count2321
# image_count2322
# image_count2323
# image_count2324
# image_count2325
# image_count2326
# image_count2327
# image_count2328
# image_count2329
# image_count2330
# image_count2331
# image_count2332
# image_count2333
# image_count2334
# image_count2335
# image_count2336
# image_count2337
# image_count2338
# image_count2339
# image_count2340
# image_count2341
# image_count2342
# image_count2343
# image_count2344
# image_count2345
# image_count2346
# image_count2347
# image_count2348
# image_count2349
# image_count2350
# image_count2351
# image_count2352
# image_count2353
# image_count2354
# image_count2355
# image_count2356
# image_count2357
# image_count2358
# image_count2359
# image_count2360
# image_count2361
# image_count2362
# image_count2363
# image_count2364
# image_count2365
# image_count2366
# image_count2367
# image_count2368
# image_count2369
# image_count2370
# image_count2371
# image_count2372
# image_count2373
# image_count2374
# image_count2375
# image_count2376
# image_count2377
# image_count2378
# image_count2379
# image_count2380
# image_count2381
# image_count2382
# image_count2383
# image_count2384
# image_count2385
# image_count2386
# image_count2387
# image_count2388
# image_count2389
# image_count2390
# image_count2391
# image_count2392
# image_count2393
# image_count2394
# image_count2395
# image_count2396
# image_count2397
# image_count2398
# image_count2399
# image_count2400
# image_count2401
# image_count2402
# image_count2403
# image_count2404
# image_count2405
# image_count2406
# image_count2407
# image_count2408
# image_count2409
# image_count2410
# image_count2411
# image_count2412
# image_count2413
# image_count2414
# image_count2415
# image_count2416
# image_count2417
# image_count2418
# image_count2419
# image_count2420
# image_count2421
# image_count2422
# image_count2423
# image_count2424
# image_count2425
# image_count2426
# image_count2427
# image_count2428
# image_count2429
# image_count2430
# image_count2431
# image_count2432
# image_count2433
# image_count2434
# image_count2435
# image_count2436
# image_count2437
# image_count2438
# image_count2439
# image_count2440
# image_count2441
# image_count2442
# image_count2443
# image_count2444
# image_count2445
# image_count2446
# image_count2447
# image_count2448
# image_count2449
# image_count2450
# image_count2451
# image_count2452
# image_count2453
# image_count2454
# image_count2455
# image_count2456
# image_count2457
# image_count2458
# image_count2459
# image_count2460
# image_count2461
# image_count2462
# image_count2463
# image_count2464
# image_count2465
# image_count2466
# image_count2467
# image_count2468
# image_count2469
# image_count2470
# image_count2471
# image_count2472
# image_count2473
# image_count2474
# image_count2475
# image_count2476
# image_count2477
# image_count2478
# image_count2479
# image_count2480
# image_count2481
# image_count2482
# image_count2483
# image_count2484
# image_count2485
# image_count2486
# image_count2487
# image_count2488
# image_count2489
# image_count2490
# image_count2491
# image_count2492
# image_count2493
# image_count2494
# image_count2495
# image_count2496
# image_count2497
# image_count2498
# image_count2499
# image_count2500
# image_count2501
# image_count2502
# image_count2503
# image_count2504
# image_count2505
# image_count2506
# image_count2507
# image_count2508
# image_count2509
# image_count2510
# image_count2511
# image_count2512
# image_count2513
# image_count2514
# image_count2515
# image_count2516
# image_count2517
# image_count2518
# image_count2519
# image_count2520
# image_count2521
# image_count2522
# image_count2523
# image_count2524
# image_count2525
# image_count2526
# image_count2527
# image_count2528
# image_count2529
# image_count2530
# image_count2531
# image_count2532
# image_count2533
# image_count2534
# image_count2535
# image_count2536
# image_count2537
# image_count2538
# image_count2539
# image_count2540
# image_count2541
# image_count2542
# image_count2543
# image_count2544
# image_count2545
# image_count2546
# image_count2547
# image_count2548
# image_count2549
# image_count2550
# image_count2551
# image_count2552
# image_count2553
# image_count2554
# image_count2555
# image_count2556
# image_count2557
# image_count2558
# image_count2559
# image_count2560
# image_count2561
# image_count2562
# image_count2563
# image_count2564
# image_count2565
# image_count2566
# image_count2567
# image_count2568
# image_count2569
# image_count2570
# image_count2571
# image_count2572
# image_count2573
# image_count2574
# image_count2575
# image_count2576
# image_count2577
# image_count2578
# image_count2579
# image_count2580
# image_count2581
# image_count2582
# image_count2583
# image_count2584
# image_count2585
# image_count2586
# image_count2587
# image_count2588
# image_count2589
# image_count2590
# image_count2591
# image_count2592
# image_count2593
# image_count2594
# image_count2595
# image_count2596
# image_count2597
# image_count2598
# image_count2599
# image_count2600
# image_count2601
# image_count2602
# image_count2603
# image_count2604
# image_count2605
# image_count2606
# image_count2607
# image_count2608
# image_count2609
# image_count2610
# image_count2611
# image_count2612
# image_count2613
# image_count2614
# image_count2615
# image_count2616
# image_count2617
# image_count2618
# image_count2619
# image_count2620
# image_count2621
# image_count2622
# image_count2623
# image_count2624
# image_count2625
# image_count2626
# image_count2627
# image_count2628
# image_count2629
# image_count2630
# image_count2631
# image_count2632
# image_count2633
# image_count2634
# image_count2635
# image_count2636
# image_count2637
# image_count2638
# image_count2639
# image_count2640
# image_count2641
# image_count2642
# image_count2643
# image_count2644
# image_count2645
# image_count2646
# image_count2647
# image_count2648
# image_count2649
# image_count2650
# image_count2651
# image_count2652
# image_count2653
# image_count2654
# image_count2655
# image_count2656
# image_count2657
# image_count2658
# image_count2659
# image_count2660
# image_count2661
# image_count2662
# image_count2663
# image_count2664
# image_count2665
# image_count2666
# image_count2667
# image_count2668
# image_count2669
# image_count2670
# image_count2671
# image_count2672
# image_count2673
# image_count2674
# image_count2675
# image_count2676
# image_count2677
# image_count2678
# image_count2679
# image_count2680
# image_count2681
# image_count2682
# image_count2683
# image_count2684
# image_count2685
# image_count2686
# image_count2687
# image_count2688
# image_count2689
# image_count2690
# image_count2691
# image_count2692
# image_count2693
# image_count2694
# image_count2695
# image_count2696
# image_count2697
# image_count2698
# image_count2699
# image_count2700
# image_count2701
# image_count2702
# image_count2703
# image_count2704
# image_count2705
# image_count2706
# image_count2707
# image_count2708
# image_count2709
# image_count2710
# image_count2711
# image_count2712
# image_count2713
# image_count2714
# image_count2715
# image_count2716
# image_count2717
# image_count2718
# image_count2719
# image_count2720
# image_count2721
# image_count2722
# image_count2723
# image_count2724
# image_count2725
# image_count2726
# image_count2727
# image_count2728
# image_count2729
# image_count2730
# image_count2731
# image_count2732
# image_count2733
# image_count2734
# image_count2735
# image_count2736
# image_count2737
# image_count2738
# image_count2739
# image_count2740
# image_count2741
# image_count2742
# image_count2743
# image_count2744
# image_count2745
# image_count2746
# image_count2747
# image_count2748
# image_count2749
# image_count2750
# image_count2751
# image_count2752
# image_count2753
# image_count2754
# image_count2755
# image_count2756
# image_count2757
# image_count2758
# image_count2759
# image_count2760
# image_count2761
# image_count2762
# image_count2763
# image_count2764
# image_count2765
# image_count2766
# image_count2767
# image_count2768
# image_count2769
# image_count2770
# image_count2771
# image_count2772
# image_count2773
# image_count2774
# image_count2775
# image_count2776
# image_count2777
# image_count2778
# image_count2779
# image_count2780
# image_count2781
# image_count2782
# image_count2783
# image_count2784
# image_count2785
# image_count2786
# image_count2787
# image_count2788
# image_count2789
# image_count2790
# image_count2791
# image_count2792
# image_count2793
# image_count2794
# image_count2795
# image_count2796
# image_count2797
# image_count2798
# image_count2799
# image_count2800
# image_count2801
# image_count2802
# image_count2803
# image_count2804
# image_count2805
# image_count2806
# image_count2807
# image_count2808
# image_count2809
# image_count2810
# image_count2811
# image_count2812
# image_count2813
# image_count2814
# image_count2815
# image_count2816
# image_count2817
# image_count2818
# image_count2819
# image_count2820
# image_count2821
# image_count2822
# image_count2823
# image_count2824
# image_count2825
# image_count2826
# image_count2827
# image_count2828
# image_count2829
# image_count2830
# image_count2831
# image_count2832
# image_count2833
# image_count2834
# image_count2835
# image_count2836
# image_count2837
# image_count2838
# image_count2839
# image_count2840
# image_count2841
# image_count2842
# image_count2843
# image_count2844
# image_count2845
# image_count2846
# image_count2847
# image_count2848
# image_count2849
# image_count2850
# image_count2851
# image_count2852
# image_count2853
# image_count2854
# image_count2855
# image_count2856
# image_count2857
# image_count2858
# image_count2859
# image_count2860
# image_count2861
# image_count2862
# image_count2863
# image_count2864
# image_count2865
# image_count2866
# image_count2867
# image_count2868
# image_count2869
# image_count2870
# image_count2871
# image_count2872
# image_count2873
# image_count2874
# image_count2875
# image_count2876
# image_count2877
# image_count2878
# image_count2879
# image_count2880
# image_count2881
# image_count2882
# image_count2883
# image_count2884
# image_count2885
# image_count2886
# image_count2887
# image_count2888
# image_count2889
# image_count2890
# image_count2891
# image_count2892
# image_count2893
# image_count2894
# image_count2895
# image_count2896
# image_count2897
# image_count2898
# image_count2899
# image_count2900
# image_count2901
# image_count2902
# image_count2903
# image_count2904
# image_count2905
# image_count2906
# image_count2907
# image_count2908
# image_count2909
# image_count2910
# image_count2911
# image_count2912
# image_count2913
# image_count2914
# image_count2915
# image_count2916
# image_count2917
# image_count2918
# image_count2919
# image_count2920
# image_count2921
# image_count2922
# image_count2923
# image_count2924
# image_count2925
# image_count2926
# image_count2927
# image_count2928
# image_count2929
# image_count2930
# image_count2931
# image_count2932
# image_count2933
# image_count2934
# image_count2935
# image_count2936
# image_count2937
# image_count2938
# image_count2939
# image_count2940
# image_count2941
# image_count2942
# image_count2943
# image_count2944
# image_count2945
# image_count2946
# image_count2947
# image_count2948
# image_count2949
# image_count2950
# image_count2951
# image_count2952
# image_count2953
# image_count2954
# image_count2955
# image_count2956
# image_count2957
# image_count2958
# image_count2959
# image_count2960
# image_count2961
# image_count2962
# image_count2963
# image_count2964
# image_count2965
# image_count2966
# image_count2967
# image_count2968
# image_count2969
# image_count2970
# image_count2971
# image_count2972
# image_count2973
# image_count2974
# image_count2975
# image_count2976
# image_count2977
# image_count2978
# image_count2979
# image_count2980
# image_count2981
# image_count2982
# image_count2983
# image_count2984
# image_count2985
# image_count2986
# image_count2987
# image_count2988
# image_count2989
# image_count2990
# image_count2991
# image_count2992
# image_count2993
# image_count2994
# image_count2995
# image_count2996
# image_count2997
# image_count2998
# image_count2999
# image_count3000
# image_count3001
# image_count3002
# image_count3003
# image_count3004
# image_count3005
# image_count3006
# image_count3007
# image_count3008
# image_count3009
# image_count3010
# image_count3011
# image_count3012
# image_count3013
# image_count3014
# image_count3015
# image_count3016
# image_count3017
# image_count3018
# image_count3019
# image_count3020
# image_count3021
# image_count3022
# image_count3023
# image_count3024
# image_count3025
# image_count3026
# image_count3027
# image_count3028
# image_count3029
# image_count3030
# image_count3031
# image_count3032
# image_count3033
# image_count3034
# image_count3035
# image_count3036
# image_count3037
# image_count3038
# image_count3039
# image_count3040
# image_count3041
# image_count3042
# image_count3043
# image_count3044
# image_count3045
# image_count3046
# image_count3047
# image_count3048
# image_count3049
# image_count3050
# image_count3051
# image_count3052
# image_count3053
# image_count3054
# image_count3055
# image_count3056
# image_count3057
# image_count3058
# image_count3059
# image_count3060
# image_count3061
# image_count3062
# image_count3063
# image_count3064
# image_count3065
# image_count3066
# image_count3067
# image_count3068
# image_count3069
# image_count3070
# ...
# image_count3747
# image_count3748
# image_count3749
# image_count3750
# image_count3751
# image_count3752
# image_count3753
# image_count3754
# image_count3755
# image_count3756
# image_count3757
# image_count3758
# image_count3759
# image_count3760
# image_count3761
# image_count3762
# image_count3763
# image_count3764
# image_count3765
# image_count3766
# image_count3767
# image_count3768
# image_count3769
# image_count3770
# image_count3771
# image_count3772
# image_count3773
# image_count3774
# image_count3775
# image_count3776
# image_count3777
# image_count3778
# image_count3779
# image_count3780
# image_count3781
# image_count3782
# image_count3783
# image_count3784
# image_count3785
# image_count3786
# image_count3787
# image_count3788
# image_count3789
# image_count3790
# image_count3791
# image_count3792
# image_count3793
# image_count3794
# image_count3795
# image_count3796
# image_count3797
# image_count3798
# image_count3799
# image_count3800
# image_count3801
# image_count3802
# image_count3803
# image_count3804
# image_count3805
# image_count3806
# image_count3807
# image_count3808
# image_count3809
# image_count3810
# image_count3811
# image_count3812
# image_count3813
# image_count3814
# image_count3815
# image_count3816
# image_count3817
# image_count3818
# image_count3819
# image_count3820
# image_count3821
# image_count3822
# image_count3823
# image_count3824
# image_count3825
# image_count3826
# image_count3827
# image_count3828
# image_count3829
# image_count3830
# image_count3831
# image_count3832
# image_count3833
# image_count3834
# image_count3835
# image_count3836
# image_count3837
# image_count3838
# image_count3839
# image_count3840
# image_count3841
# image_count3842
# image_count3843
# image_count3844
# image_count3845
# image_count3846
# image_count3847
# image_count3848
# image_count3849
# image_count3850
# image_count3851
# image_count3852
# image_count3853
# image_count3854
# image_count3855
# image_count3856
# image_count3857
# image_count3858
# image_count3859
# image_count3860
# image_count3861
# image_count3862
# image_count3863
# image_count3864
# image_count3865
# image_count3866
# image_count3867
# image_count3868
# image_count3869
# image_count3870
# image_count3871
# image_count3872
# image_count3873
# image_count3874
# image_count3875
# image_count3876
# image_count3877
# image_count3878
# image_count3879
# image_count3880
# image_count3881
# image_count3882
# image_count3883
# image_count3884
# image_count3885
# image_count3886
# image_count3887
# image_count3888
# image_count3889
# image_count3890
# image_count3891
# image_count3892
# image_count3893
# image_count3894
# image_count3895
# image_count3896
# image_count3897
# image_count3898
# image_count3899
# image_count3900
# image_count3901
# image_count3902
# image_count3903
# image_count3904
# image_count3905
# image_count3906
# image_count3907
# image_count3908
# image_count3909
# image_count3910
# image_count3911
# image_count3912
# image_count3913
# image_count3914
# image_count3915
# image_count3916
# image_count3917
# image_count3918
# image_count3919
# image_count3920
# image_count3921
# image_count3922
# image_count3923
# image_count3924
# image_count3925
# image_count3926
# image_count3927
# image_count3928
# image_count3929
# image_count3930
# image_count3931
# image_count3932
# image_count3933
# image_count3934
# image_count3935
# image_count3936
# image_count3937
# image_count3938
# image_count3939
# image_count3940
# image_count3941
# image_count3942
# image_count3943
# image_count3944
# image_count3945
# image_count3946
# image_count3947
# image_count3948
# image_count3949
# image_count3950
# image_count3951
# image_count3952
# image_count3953
# image_count3954
# image_count3955
# image_count3956
# image_count3957
# image_count3958
# image_count3959
# image_count3960
# image_count3961
# image_count3962
# image_count3963
# image_count3964
# image_count3965
# image_count3966
# image_count3967
# image_count3968
# image_count3969
# image_count3970
# image_count3971
# image_count3972
# image_count3973
# image_count3974
# image_count3975
# image_count3976
# image_count3977
# image_count3978
# image_count3979
# image_count3980
# image_count3981
# image_count3982
# image_count3983
# image_count3984
# image_count3985
# image_count3986
# image_count3987
# image_count3988
# image_count3989
# image_count3990
# image_count3991
# image_count3992
# image_count3993
# image_count3994
# image_count3995
# image_count3996
# image_count3997
# image_count3998
# image_count3999
# image_count4000
# image_count4001
# image_count4002
# image_count4003
# image_count4004
# image_count4005
# image_count4006
# image_count4007
# image_count4008
# image_count4009
# image_count4010
# image_count4011
# image_count4012
# image_count4013
# image_count4014
# image_count4015
# image_count4016
# image_count4017
# image_count4018
# image_count4019
# image_count4020
# image_count4021
# image_count4022
# image_count4023
# image_count4024
# image_count4025
# image_count4026
# image_count4027
# image_count4028
# image_count4029
# image_count4030
# image_count4031
# image_count4032
# image_count4033
# image_count4034
# image_count4035
# image_count4036
# image_count4037
# image_count4038
# image_count4039
# image_count4040
# image_count4041
# image_count4042
# image_count4043
# image_count4044
# image_count4045
# image_count4046
# image_count4047
# image_count4048
# image_count4049
# image_count4050
# image_count4051
# image_count4052
# image_count4053
# image_count4054
# image_count4055
# image_count4056
# image_count4057
# image_count4058
# image_count4059
# image_count4060
# image_count4061
# image_count4062
# image_count4063
# image_count4064
# image_count4065
# image_count4066
# image_count4067
# image_count4068
# image_count4069
# image_count4070
# image_count4071
# image_count4072
# image_count4073
# image_count4074
# image_count4075
# image_count4076
# image_count4077
# image_count4078
# image_count4079
# image_count4080
# image_count4081
# image_count4082
# image_count4083
# image_count4084
# image_count4085
# image_count4086
# image_count4087
# image_count4088
# image_count4089
# image_count4090
# image_count4091
# image_count4092
# image_count4093
# image_count4094
# image_count4095
# image_count4096
# image_count4097
# image_count4098
# image_count4099
# image_count4100
# image_count4101
# image_count4102
# image_count4103
# image_count4104
# image_count4105
# image_count4106
# image_count4107
# image_count4108
# image_count4109
# image_count4110
# image_count4111
# image_count4112
# image_count4113
# image_count4114
# image_count4115
# image_count4116
# image_count4117
# image_count4118
# image_count4119
# image_count4120
# image_count4121
# image_count4122
# image_count4123
# image_count4124
# image_count4125
# image_count4126
# image_count4127
# image_count4128
# image_count4129
# image_count4130
# image_count4131
# image_count4132
# image_count4133
# image_count4134
# image_count4135
# image_count4136
# image_count4137
# image_count4138
# image_count4139
# image_count4140
# image_count4141
# image_count4142
# image_count4143
# image_count4144
# image_count4145
# image_count4146
# image_count4147
# image_count4148
# image_count4149
# image_count4150
# image_count4151
# image_count4152
# image_count4153
# image_count4154
# image_count4155
# image_count4156
# image_count4157
# image_count4158
# image_count4159
# image_count4160
# image_count4161
# image_count4162
# image_count4163
# image_count4164
# image_count4165
# image_count4166
# image_count4167
# image_count4168
# image_count4169
# image_count4170
# image_count4171
# image_count4172
# image_count4173
# image_count4174
# image_count4175
# image_count4176
# image_count4177
# image_count4178
# image_count4179
# image_count4180
# image_count4181
# image_count4182
# image_count4183
# image_count4184
# image_count4185
# image_count4186
# image_count4187
# image_count4188
# image_count4189
# image_count4190
# image_count4191
# image_count4192
# image_count4193
# image_count4194
# image_count4195
# image_count4196
# image_count4197
# image_count4198
# image_count4199
# image_count4200
# image_count4201
# image_count4202
# image_count4203
# image_count4204
# image_count4205
# image_count4206
# image_count4207
# image_count4208
# image_count4209
# image_count4210
# image_count4211
# image_count4212
# image_count4213
# image_count4214
# image_count4215
# image_count4216
# image_count4217
# image_count4218
# image_count4219
# image_count4220
# image_count4221
# image_count4222
# image_count4223
# image_count4224
# image_count4225
# image_count4226
# image_count4227
# image_count4228
# image_count4229
# image_count4230
# image_count4231
# image_count4232
# image_count4233
# image_count4234
# image_count4235
# image_count4236
# image_count4237
# image_count4238
# image_count4239
# image_count4240
# image_count4241
# image_count4242
# image_count4243
# image_count4244
# image_count4245
# image_count4246
# image_count4247
# image_count4248
# image_count4249
# image_count4250
# image_count4251
# image_count4252
# image_count4253
# image_count4254
# image_count4255
# image_count4256
# image_count4257
# image_count4258
# image_count4259
# image_count4260
# image_count4261
# image_count4262
# image_count4263
# image_count4264
# image_count4265
# image_count4266
# image_count4267
# image_count4268
# image_count4269
# image_count4270
# image_count4271
# image_count4272
# image_count4273
# image_count4274
# image_count4275
# image_count4276
# image_count4277
# image_count4278
# image_count4279
# image_count4280
# image_count4281
# image_count4282
# image_count4283
# image_count4284
# image_count4285
# image_count4286
# image_count4287
# image_count4288
# image_count4289
# image_count4290
# image_count4291
# image_count4292
# image_count4293
# image_count4294
# image_count4295
# image_count4296
# image_count4297
# image_count4298
# image_count4299
# image_count4300
# image_count4301
# image_count4302
# image_count4303
# image_count4304
# image_count4305
# image_count4306
# image_count4307
# image_count4308
# image_count4309
# image_count4310
# image_count4311
# image_count4312
# image_count4313
# image_count4314
# image_count4315
# image_count4316
# image_count4317
# image_count4318
# image_count4319
# image_count4320
# image_count4321
# image_count4322
# image_count4323
# image_count4324
# image_count4325
# image_count4326
# image_count4327
# image_count4328
# image_count4329
# image_count4330
# image_count4331
# image_count4332
# image_count4333
# image_count4334
# image_count4335
# image_count4336
# image_count4337
# image_count4338
# image_count4339
# image_count4340
# image_count4341
# image_count4342
# image_count4343
# image_count4344
# image_count4345
# image_count4346
# image_count4347
# image_count4348
# image_count4349
# image_count4350
# image_count4351
# image_count4352
# image_count4353
# image_count4354
# image_count4355
# image_count4356
# image_count4357
# image_count4358
# image_count4359
# image_count4360
# image_count4361
# image_count4362
# image_count4363
# image_count4364
# image_count4365
# image_count4366
# image_count4367
# image_count4368
# image_count4369
# image_count4370
# image_count4371
# image_count4372
# image_count4373
# image_count4374
# image_count4375
# image_count4376
# image_count4377
# image_count4378
# image_count4379
# image_count4380
# image_count4381
# image_count4382
# image_count4383
# image_count4384
# image_count4385
# image_count4386
# image_count4387
# image_count4388
# image_count4389
# image_count4390
# image_count4391
# image_count4392
# image_count4393
# image_count4394
# image_count4395
# image_count4396
# image_count4397
# image_count4398
# image_count4399
# image_count4400
# image_count4401
# image_count4402
# image_count4403
# image_count4404
# image_count4405
# image_count4406
# image_count4407
# image_count4408
# image_count4409
# image_count4410
# image_count4411
# image_count4412
# image_count4413
# image_count4414
# image_count4415
# image_count4416
# image_count4417
# image_count4418
# image_count4419
# image_count4420
# image_count4421
# image_count4422
# image_count4423
# image_count4424
# image_count4425
# image_count4426
# image_count4427
# image_count4428
# image_count4429
# image_count4430
# image_count4431
# image_count4432
# image_count4433
# image_count4434
# image_count4435
# image_count4436
# image_count4437
# image_count4438
# image_count4439
# image_count4440
# image_count4441
# image_count4442
# image_count4443
# image_count4444
# image_count4445
# image_count4446
# image_count4447
# image_count4448
# image_count4449
# image_count4450
# image_count4451
# image_count4452
# image_count4453
# image_count4454
# image_count4455
# image_count4456
# image_count4457
# image_count4458
# image_count4459
# image_count4460
# image_count4461
# image_count4462
# image_count4463
# image_count4464
# image_count4465
# image_count4466
# image_count4467
# image_count4468
# image_count4469
# image_count4470
# image_count4471
# image_count4472
# image_count4473
# image_count4474
# image_count4475
# image_count4476
# image_count4477
# image_count4478
# image_count4479
# image_count4480
# image_count4481
# image_count4482
# image_count4483
# image_count4484
# image_count4485
# image_count4486
# image_count4487
# image_count4488
# image_count4489
# image_count4490
# image_count4491
# image_count4492
# image_count4493
# image_count4494
# image_count4495
# image_count4496
# image_count4497
# image_count4498
# image_count4499
# image_count4500
# image_count4501
# image_count4502
# image_count4503
# image_count4504
# image_count4505
# image_count4506
# image_count4507
# image_count4508
# image_count4509
# image_count4510
# image_count4511
# image_count4512
# image_count4513
# image_count4514
# image_count4515
# image_count4516
# image_count4517
# image_count4518
# image_count4519
# image_count4520
# image_count4521
# image_count4522
# image_count4523
# image_count4524
# image_count4525
# image_count4526
# image_count4527
# image_count4528
# image_count4529
# image_count4530
# image_count4531
# image_count4532
# image_count4533
# image_count4534
# image_count4535
# image_count4536
# image_count4537
# image_count4538
# image_count4539
# image_count4540
# image_count4541
# image_count4542
# image_count4543
# image_count4544
# image_count4545
# image_count4546
# image_count4547
# image_count4548
# image_count4549
# image_count4550
# image_count4551
# image_count4552
# image_count4553
# image_count4554
# image_count4555
# image_count4556
# image_count4557
# image_count4558
# image_count4559
# image_count4560
# image_count4561
# image_count4562
# image_count4563
# image_count4564
# image_count4565
# image_count4566
# image_count4567
# image_count4568
# image_count4569
# image_count4570
# image_count4571
# image_count4572
# image_count4573
# image_count4574
# image_count4575
# image_count4576
# image_count4577
# image_count4578
# image_count4579
# image_count4580
# image_count4581
# image_count4582
# image_count4583
# image_count4584
# image_count4585
# image_count4586
# image_count4587
# image_count4588
# image_count4589
# image_count4590
# image_count4591
# image_count4592
# image_count4593
# image_count4594
# image_count4595
# image_count4596
# image_count4597
# image_count4598
# image_count4599
# image_count4600
# image_count4601
# image_count4602
# image_count4603
# image_count4604
# image_count4605
# image_count4606
# image_count4607
# image_count4608
# image_count4609
# image_count4610
# image_count4611
# image_count4612
# image_count4613
# image_count4614
# image_count4615
# image_count4616
# image_count4617
# image_count4618
# image_count4619
# image_count4620
# image_count4621
# image_count4622
# image_count4623
# image_count4624
# image_count4625
# image_count4626
# image_count4627
# image_count4628
# image_count4629
# image_count4630
# image_count4631
# image_count4632
# image_count4633
# image_count4634
# image_count4635
# image_count4636
# image_count4637
# image_count4638
# image_count4639
# image_count4640
# image_count4641
# image_count4642
# image_count4643
# image_count4644
# image_count4645
# image_count4646
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 9
#       6 if not os.path.exists(train_path):
#       7     os.makedirs(train_path)
# ----> 9 process_images(source_folder, train_path)
#
# Cell In[7], line 33, in process_images(source_folder, target_folder)
#      30 image_path = os.path.join(folder_path, f"{i:06}.jpg")
#      31 target_image_path = os.path.join(image_folder_path, image_name)
# ---> 33 shutil.copy(image_path, target_image_path)
#      35 if exist == 1:
#      36     txt_file_path = os.path.join(label_folder, txt_name)
#
# File c:\Users\Limumu\AppData\Local\Programs\Python\Python311\Lib\shutil.py:419, in copy(src, dst, follow_symlinks)
#     417 if os.path.isdir(dst):
#     418     dst = os.path.join(dst, os.path.basename(src))
# --> 419 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     420 copymode(src, dst, follow_symlinks=follow_symlinks)
#     421 return dst
#
# File c:\Users\Limumu\AppData\Local\Programs\Python\Python311\Lib\shutil.py:276, in copyfile(src, dst, follow_symlinks)
#     273 # Windows, see:
#     274 # https://github.com/python/cpython/pull/7160#discussion_r195405230
#     275 elif _WINDOWS and file_size > 0:
# --> 276     _copyfileobj_readinto(fsrc, fdst, min(file_size, COPY_BUFSIZE))
#     277     return dst
#     279 copyfileobj(fsrc, fdst)
#
# File c:\Users\Limumu\AppData\Local\Programs\Python\Python311\Lib\shutil.py:187, in _copyfileobj_readinto(fsrc, fdst, length)
#     185         fdst.write(smv)
#     186 else:
# --> 187     fdst_write(mv)
#
# KeyboardInterrupt:
